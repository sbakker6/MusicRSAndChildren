# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
from pathlib import Path

# %%
EXCEL_PATH = Path("C:/", "Users", "sanba", "Documents", "TU", "CSE", "Jaar 3", "Q4", "saved_queries", "analysis.xlsx")

# %%
df = pd.read_excel(EXCEL_PATH, "user_stats")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1561 entries, 0 to 1560
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   user_id           1561 non-null   int64
#  1   country           1452 non-null   object
#  2   distinct_les      1561 non-null   int64
#  3   distinct_tracks   1561 non-null   int64
#  4   distinct_artists  1561 non-null   int64
# dtypes: int64(4), object(1)
# memory usage: 61.1+ KB

# %%
# https://python-graph-gallery.com/bubble-plot-with-seaborn/
sns.scatterplot(
    data=df,
    x="distinct_artists",
    y="distinct_tracks",
    size="distinct_les",
    hue="country",
    alpha=0.5,
    legend=False,
    sizes=(1, 1000)
)

## Size = #listening events
## Color = user country
plt.title("User listening diversity")
plt.show()
